# %%
from img2net import *
# Out:
# Init Plugin
# Init Graph Optimizer
# Init Kernel

# %%
test_path = "/Users/behnazyazdani/U_Net_Neurite_NVersion/prediction_pipeline_Cell+Neurite"
cell_model_path = "DHM_Cell.hdf5"
neurite_model_path = "DHM_Neurite.hdf5"
patchsize = 128
overlap = 0.1

cell_mask, neurite_mask = predict_and_segment(test_path, cell_model_path, neurite_model_path, patchsize, overlap)
# Out:
# Metal device set to: Apple M1
# 2023-04-21 15:48:54.987736: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-04-21 15:48:54.987841: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# /Users/behnazyazdani/miniforge3/envs/tensorflow/lib/python3.9/site-packages/keras/engine/training.py:1976: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   warnings.warn('`Model.predict_generator` is deprecated and '
# ...
